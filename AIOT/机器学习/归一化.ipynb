# %% [markdown]
# 归一化：将不同的数值缩放到同一个区间内，便于梯度下降 归一化也叫标准化
#
# 归一化的一个目的是，使得梯度下降在不同维度 $\theta$ 参数（不同数量级）上，可以步调一致协同的进行梯度下降。

# %% [markdown]
# ### 最大值最小值归一化
# 也称为差值标准化
#
# 公式： $X^* = \frac{X - X\_min}{X\_max -X\_min}$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x1 = np.random.randint(1, 10, size=10)

# %%
x2 = np.random.randint(1000, 5000, size=10)
x = np.c_[x1, x2]  # 按行拼接
x
# Out:
# array([[   8, 4706],
#        [   9, 2511],
#        [   4, 4401],
#        [   5, 3809],
#        [   6, 2225],
#        [   7, 1054],
#        [   7, 4601],
#        [   9, 4247],
#        [   3, 3495],
#        [   3, 2901]])

# %%
x.min(axis=0)  # 按列计算最小值
# Out:
# array([   3, 1054])

# %% [markdown]
# ### 使用公式进行最大值最小值归一化处理

# %%
X = (x-x.min(axis=0)) / (x.max(axis=0)-x.min(axis=0))
X.round(2)
# Out:
# array([[0.83, 1.  ],
#        [1.  , 0.4 ],
#        [0.17, 0.92],
#        [0.33, 0.75],
#        [0.5 , 0.32],
#        [0.67, 0.  ],
#        [0.67, 0.97],
#        [1.  , 0.87],
#        [0.  , 0.67],
#        [0.  , 0.51]])

# %%
# 使用sklearn进行归一化处理
from sklearn.preprocessing import MinMaxScaler

# %%
x1 = np.random.randint(1, 10, size=10)
x2 = np.random.randint(1000, 5000, size=10)
x = np.c_[x1, x2]
X = MinMaxScaler()
y = X.fit_transform(x)
y.round(2)
# Out:
# array([[0.  , 0.42],
#        [0.38, 0.15],
#        [0.25, 0.94],
#        [0.5 , 0.72],
#        [0.25, 1.  ],
#        [0.  , 0.  ],
#        [0.62, 0.08],
#        [1.  , 0.27],
#        [0.25, 0.96],
#        [0.88, 0.62]])

# %% [markdown]
# ### 使用z-score归一化
#
# 公式：  $X^* = \frac{X - \mu}{\sigma}$
#
# X:x数据
# $\mu$:均值
# $\sigma$:标准差
#
# 归一化后的数据符合正态分布，均值为0， 标准差为1
#
# 该标准化后得出的数据，不一定全在0-1之间，也会有负数

# %%
x1 = np.random.randint(1, 100, size=(10, 2))
x2 = np.random.randint(1000, 10000, size=(10, 2))
x = np.concatenate([x1, x2])
x
# Out:
# array([[  94,    6],
#        [  13,   26],
#        [  77,   57],
#        [  84,   14],
#        [  20,   67],
#        [  42,   39],
#        [  68,    1],
#        [  24,   96],
#        [  23,   46],
#        [  19,   55],
#        [8048, 7418],
#        [8685, 3303],
#        [7122, 4400],
#        [1725, 3955],
#        [6168, 8959],
#        [3067, 1181],
#        [9548, 5144],
#        [6413, 6290],
#        [4986, 3528],
#        [1704, 8630]])

# %% [markdown]
# ### 使用公式进行均值归一化

# %%
np.set_printoptions(suppress=True)  # 不使用科学计数法进行输出
X = (x - x.mean(axis=0)) / x.std(axis=0)
X
# Out:
# array([[-0.81995033, -0.85243668],
#        [-0.84364916, -0.8460147 ],
#        [-0.82492416, -0.83606064],
#        [-0.82287611, -0.84986789],
#        [-0.84160112, -0.83284966],
#        [-0.8351644 , -0.84184042],
#        [-0.82755736, -0.85404217],
#        [-0.8404308 , -0.8235378 ],
#        [-0.84072338, -0.83959273],
#        [-0.84189369, -0.83670284],
#        [ 1.50721646,  1.52754662],
#        [ 1.69358876,  0.20622562],
#        [ 1.23628907,  0.55847085],
#        [-0.34275533,  0.41558194],
#        [ 0.95716949,  2.02235966],
#        [ 0.04988458, -0.47514575],
#        [ 1.94608372,  0.79736826],
#        [ 1.02885115,  1.16534732],
#        [ 0.61134209,  0.27847282],
#        [-0.34889947,  1.9167182 ]])

# %% [markdown]
# ### 使用sklearn进行0均值归一化

# %%
# preprocessing:预处理
from sklearn.preprocessing import StandardScaler

# %%
x1 = np.random.randint(1, 100, size= (10, 10))
x2 = np.random.randint(1000, 10000, size=(10, 10))
X = np.c_[x1, x2]
X
x = StandardScaler()
y = x.fit_transform(X)
y
# Out:
# array([[ 0.05581101, -0.69232086,  0.29801825, -1.16093959, -0.62284954,
#          0.40969106, -1.33241682,  1.37778839, -1.15035515, -1.34799993,
#          1.31762337,  0.83734221, -0.87397039,  0.64530721, -1.0670018 ,
#         -0.84349735,  1.09352083, -0.26847203,  0.47506227,  0.23899582],
#        [ 1.05243617, -1.74015783,  2.08612774,  1.0832559 ,  0.74105456,
#         -0.82890983,  0.07918756,  1.61533811, -0.37253494,  0.80482551,
#         -0.56429945,  1.07477113, -0.96525294,  0.02373796,  0.7476778 ,
#          1.4861028 ,  1.57017211,  1.1922972 ,  1.60973203, -0.97575833],
#        [-1.29959921,  0.72974361, -0.26076597,  0.39273421,  1.10476232,
#          0.60024505, -0.85040557, -0.52260939, -0.49534866, -0.78495327,
#          0.85477101,  0.75486188,  1.15526478, -1.84389141,  1.3869533 ,
#          0.02310952,  0.07659746,  0.34685314,  1.72341418, -0.22129242],
#        [ 1.92946631,  0.76716636, -0.93130703, -1.2472548 , -0.16821484,
#         -0.97182532,  1.62850944,  0.46718112,  1.91998777, -1.18239797,
#          0.56945106, -1.15601187, -0.6637803 ,  0.68620954, -1.30584767,
#         -0.93856815, -1.20591763,  0.68951925, -0.33326441, -1.02886851],
#        [-1.29959921,  1.66531234, -0.63328878, -0.51357551, -0.94109383,
#          0.07622159, -1.47013432, -1.19566693, -1.31410677,  1.20227021,
#          0.14384881,  0.27428285,  0.39197449,  0.90971153,  0.12526662,
#          0.46811397, -0.80349065, -1.76508219,  0.11859522, -1.19761575],
#        [-0.70162411, -0.69232086,  1.41558668, -0.68620593, -2.25953446,
#         -0.87654832,  0.56119881, -0.24546805, -0.94566562, -0.22190662,
#         -1.01209326, -1.22418925, -1.11779089,  0.19611204, -0.0131777 ,
#          1.43820174, -0.20313221, -0.52237322,  0.20538096, -1.1441289 ],
#        [-0.82121913, -0.24324787,  0.22351369,  1.29904393,  0.78651803,
#         -0.35252487,  1.31864507,  1.06105542,  0.44622317, -0.75183288,
#         -0.49178063,  1.47811424, -0.86676387,  1.04593087, -0.95248128,
#          0.84327796, -0.44145785, -1.71651271, -1.34815551,  1.44169659],
#        [ 0.015946  ,  0.01871137, -1.30382984, -1.07462438,  0.28641986,
#         -1.1623793 ,  0.45791069, -0.56220101,  0.11871993,  0.97042747,
#         -1.82129233,  0.16939457,  1.78223178, -0.13987134,  1.40303324,
#         -0.4646768 , -1.00445168,  0.87341338, -0.46918092,  1.00815177],
#        [ 0.69365111, -0.91685735, -0.26076597,  1.38535914,  1.05929885,
#          2.17231541,  0.21690506, -1.19566693,  0.60997479,  1.56659451,
#         -0.44224592, -1.17937335,  0.06527904,  0.37250331, -1.09210218,
#         -0.31329484, -0.67372436,  0.83824237, -1.14015663,  1.31362948],
#        [ 0.37473106,  1.1039711 , -0.63328878,  0.52220703,  0.01363904,
#          0.93371452, -0.60939994, -0.79975073,  1.18310547, -0.25502701,
#          1.44601734, -1.02919241,  1.0928083 , -1.89574971,  0.76767967,
#         -1.69876886,  1.59188398,  0.33211481, -0.8414272 ,  0.56519026]])
